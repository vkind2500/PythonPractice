# %% [markdown]
# ### Preparing the Dataset

# %%
import pandas as pd
import os

column_subset = [
     "id",
     "make",
     "model",
     "year",
     "cylinders",
     "fuelType",
     "trany",
     "mpgData",
     "city08",
     "highway08"
 ]


file_path = os.path.join('resources','vehicles.csv')

df = pd.read_csv(
    file_path,
    usecols=column_subset,
    nrows=100
 )


df.head()
# Out:
#    city08  cylinders fuelType  highway08     id        make  \
# 0      19          4  Regular         25      1  Alfa Romeo
# 1       9         12  Regular         14     10     Ferrari
# 2      23          4  Regular         33    100       Dodge
# 3      10          8  Regular         12   1000       Dodge
# 4      17          4  Premium         23  10000      Subaru
#
#                  model mpgData            trany  year
# 0   Spider Veloce 2000       Y     Manual 5-spd  1985
# 1           Testarossa       N     Manual 5-spd  1985
# 2              Charger       Y     Manual 5-spd  1985
# 3  B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# 4     Legacy AWD Turbo       N     Manual 5-spd  1993

# %% [markdown]
# ## Sorting Your DataFrame on a Single Column
#
# To sort the DataFrame based on the values in a single column, we’ll use ``.sort_values()``.
#
# By default, this will return a new DataFrame sorted in ascending order.
#
# It does not modify the original DataFrame.
#
# In this example, we sort the DataFrame by the ``city08`` column, which represents city MPG for fuel-only cars:

# %%
df1 = df.sort_values("city08")

print('Sort DataFrame in ascending Order')

df1
# Out:
# Sort DataFrame in ascending Order
#     city08  cylinders fuelType  highway08     id         make  \
# 99       9          8  Premium         13  10087  Rolls-Royce
# 1        9         12  Regular         14     10      Ferrari
# 80       9          8  Regular         10   1007        Dodge
# 47       9          8  Regular         11   1004        Dodge
# 3       10          8  Regular         12   1000        Dodge
# ..     ...        ...      ...        ...    ...          ...
# 76      23          4  Regular         31  10066        Mazda
# 10      23          4  Regular         30  10006       Toyota
# 9       23          4  Regular         30  10005       Toyota
# 8       23          4  Regular         31  10004       Toyota
# 2       23          4  Regular         33    100        Dodge
#
#                    model mpgData            trany  year
# 99  Brooklands/Brklnds L       N  Automatic 4-spd  1993
# 1             Testarossa       N     Manual 5-spd  1985
# 80        B350 Wagon 2WD       N  Automatic 3-spd  1985
# 47   B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# 3    B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# ..                   ...     ...              ...   ...
# 76                   626       Y     Manual 5-spd  1993
# 10               Corolla       Y     Manual 5-spd  1993
# 9                Corolla       Y  Automatic 4-spd  1993
# 8                Corolla       Y     Manual 5-spd  1993
# 2                Charger       Y     Manual 5-spd  1985
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Changing the Sort Order
#
# By default ``.sort_values()`` has ascending set to True.
#
# To sort the DataFrame in descending order, then we can pass False to this parameter.

# %%
print('Sort DataFrame in descending Order')

df2 = df.sort_values("city08",ascending=False)
df2
# Out:
# Sort DataFrame in descending Order
#     city08  cylinders fuelType  highway08     id         make  \
# 2       23          4  Regular         33    100        Dodge
# 7       23          4  Regular         26  10003       Toyota
# 8       23          4  Regular         31  10004       Toyota
# 9       23          4  Regular         30  10005       Toyota
# 10      23          4  Regular         30  10006       Toyota
# ..     ...        ...      ...        ...    ...          ...
# 3       10          8  Regular         12   1000        Dodge
# 80       9          8  Regular         10   1007        Dodge
# 1        9         12  Regular         14     10      Ferrari
# 47       9          8  Regular         11   1004        Dodge
# 99       9          8  Premium         13  10087  Rolls-Royce
#
#                    model mpgData            trany  year
# 2                Charger       Y     Manual 5-spd  1985
# 7                Corolla       Y  Automatic 3-spd  1993
# 8                Corolla       Y     Manual 5-spd  1993
# 9                Corolla       Y  Automatic 4-spd  1993
# 10               Corolla       Y     Manual 5-spd  1993
# ..                   ...     ...              ...   ...
# 3    B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# 80        B350 Wagon 2WD       N  Automatic 3-spd  1985
# 1             Testarossa       N     Manual 5-spd  1985
# 47   B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# 99  Brooklands/Brklnds L       N  Automatic 4-spd  1993
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Choosing a Sorting Algorithm
#
#
# It’s good to note that pandas allows us to choose different sorting algorithms to use with both ``.sort_values()`` and ``.sort_index()``.
#
# The available algorithms are ``quicksort``, ``mergesort``, and ``heapsort``.
#
# The algorithm used by default when sorting on a single column is ``quicksort``.
#
# To change sorting algorithm, use kind parameter in .sort_values() or .sort_index(), like this:

# %%
df3 = df.sort_values("city08",ascending=False,kind="mergesort")

df3
# Out:
#     city08  cylinders fuelType  highway08     id         make  \
# 76      23          4  Regular         31  10066        Mazda
# 10      23          4  Regular         30  10006       Toyota
# 9       23          4  Regular         30  10005       Toyota
# 8       23          4  Regular         31  10004       Toyota
# 7       23          4  Regular         26  10003       Toyota
# ..     ...        ...      ...        ...    ...          ...
# 69      10          8  Regular         11   1006        Dodge
# 99       9          8  Premium         13  10087  Rolls-Royce
# 1        9         12  Regular         14     10      Ferrari
# 80       9          8  Regular         10   1007        Dodge
# 47       9          8  Regular         11   1004        Dodge
#
#                    model mpgData            trany  year
# 76                   626       Y     Manual 5-spd  1993
# 10               Corolla       Y     Manual 5-spd  1993
# 9                Corolla       Y  Automatic 4-spd  1993
# 8                Corolla       Y     Manual 5-spd  1993
# 7                Corolla       Y  Automatic 3-spd  1993
# ..                   ...     ...              ...   ...
# 69        B350 Wagon 2WD       N  Automatic 3-spd  1985
# 99  Brooklands/Brklnds L       N  Automatic 4-spd  1993
# 1             Testarossa       N     Manual 5-spd  1985
# 80        B350 Wagon 2WD       N  Automatic 3-spd  1985
# 47   B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
#
# [100 rows x 10 columns]

# %% [markdown]
# ## Sorting Your DataFrame on Multiple Columns
#
# To sort DataFrame by two keys, we can pass a list of column names ``.sort_values``.
#
# By specifying a list of the column names ``city08`` and ``highway08``, we sort the DataFrame on two columns using ``.sort_values()``.

# %%
df4 = df.sort_values(["city08","highway08"])[["city08","highway08"]]

df4.head(20)
# Out:
#     city08  highway08
# 80       9         10
# 47       9         11
# 99       9         13
# 1        9         14
# 58      10         11
# 69      10         11
# 3       10         12
# 25      11         17
# 22      11         17
# 36      11         17
# 14      12         15
# 91      12         15
# 42      13         19
# 43      13         19
# 68      14         18
# 20      14         20
# 21      14         20
# 67      15         20
# 61      15         21
# 63      15         22

# %% [markdown]
# ### Sorting by Multiple Columns in Descending Order
#
# To sort in descending order, set ascending to False.

# %%
df5 = df.sort_values(["make","model"],ascending=False)[["make","model"]]

df5
# Out:
#           make               model
# 16       Volvo                 240
# 17       Volvo                 240
# 13  Volkswagen           Jetta III
# 15  Volkswagen           Jetta III
# 11  Volkswagen      Golf III / GTI
# ..         ...                 ...
# 21         BMW               740il
# 20         BMW                740i
# 19        Audi                 100
# 18        Audi                 100
# 0   Alfa Romeo  Spider Veloce 2000
#
# [100 rows x 2 columns]

# %% [markdown]
# Please note, with textual data, the sort is case sensitive, meaning capitalized text will appear first in ascending order and last in descending order.

# %% [markdown]
# ### Sorting by Multiple Columns With Different Sort Orders
#
# In this example, we sort your DataFrame by the make, model, and city08 columns, with the first two columns sorted in ascending order and city08 sorted in descending order.

# %%
df6 = df.sort_values(["make","model","city08"],ascending=[True,True,False])[["make","model","city08"]]

df6
# Out:
#           make               model  city08
# 0   Alfa Romeo  Spider Veloce 2000      19
# 19        Audi                 100      17
# 18        Audi                 100      17
# 20         BMW                740i      14
# 21         BMW               740il      14
# ..         ...                 ...     ...
# 11  Volkswagen      Golf III / GTI      18
# 15  Volkswagen           Jetta III      20
# 13  Volkswagen           Jetta III      18
# 17       Volvo                 240      19
# 16       Volvo                 240      18
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Sorting Your DataFrame on Its Index
#
# Sorting by column values reorders the rows in your DataFrame, so the index becomes disorganized.
#
# DataFrame can be sorted based on its row index with ``.sort_index()``.
#
# To illustrate the use of ``.sort_index()``, start by creating a new sorted DataFrame using ``.sort_values()``:

# %%
sort_df = df.sort_values(["make","model"])

sort_df
# Out:
#     city08  cylinders fuelType  highway08     id        make  \
# 0       19          4  Regular         25      1  Alfa Romeo
# 19      17          6  Premium         24  10014        Audi
# 18      17          6  Premium         22  10013        Audi
# 20      14          8  Premium         20  10015         BMW
# 21      14          8  Premium         20  10016         BMW
# ..     ...        ...      ...        ...    ...         ...
# 12      21          4  Regular         29  10008  Volkswagen
# 13      18          4  Regular         26  10009  Volkswagen
# 15      20          4  Regular         28  10010  Volkswagen
# 16      18          4  Regular         23  10011       Volvo
# 17      19          4  Regular         26  10012       Volvo
#
#                  model mpgData            trany  year
# 0   Spider Veloce 2000       Y     Manual 5-spd  1985
# 19                 100       N     Manual 5-spd  1993
# 18                 100       Y  Automatic 4-spd  1993
# 20                740i       N  Automatic 5-spd  1993
# 21               740il       N  Automatic 5-spd  1993
# ..                 ...     ...              ...   ...
# 12      Golf III / GTI       Y     Manual 5-spd  1993
# 13           Jetta III       N  Automatic 4-spd  1993
# 15           Jetta III       N     Manual 5-spd  1993
# 16                 240       Y  Automatic 4-spd  1993
# 17                 240       Y     Manual 5-spd  1993
#
# [100 rows x 10 columns]

# %% [markdown]
# We’ve created a DataFrame that’s sorted using multiple values. Notice how the row index is in no particular order. To get new DataFrame back to the original order, you can use ``.sort_index()``.
#
# The default argument for ascending in ``.sort_index()`` is ``True``.

# %%
sort_df.sort_index()
# Out:
#     city08  cylinders fuelType  highway08     id         make  \
# 0       19          4  Regular         25      1   Alfa Romeo
# 1        9         12  Regular         14     10      Ferrari
# 2       23          4  Regular         33    100        Dodge
# 3       10          8  Regular         12   1000        Dodge
# 4       17          4  Premium         23  10000       Subaru
# ..     ...        ...      ...        ...    ...          ...
# 95      17          6  Regular         25  10083      Pontiac
# 96      17          6  Regular         27  10084      Pontiac
# 97      15          6  Regular         24  10085      Pontiac
# 98      15          6  Regular         24  10086      Pontiac
# 99       9          8  Premium         13  10087  Rolls-Royce
#
#                    model mpgData            trany  year
# 0     Spider Veloce 2000       Y     Manual 5-spd  1985
# 1             Testarossa       N     Manual 5-spd  1985
# 2                Charger       Y     Manual 5-spd  1985
# 3    B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# 4       Legacy AWD Turbo       N     Manual 5-spd  1993
# ..                   ...     ...              ...   ...
# 95            Grand Prix       Y  Automatic 3-spd  1993
# 96            Grand Prix       N  Automatic 4-spd  1993
# 97            Grand Prix       N  Automatic 4-spd  1993
# 98            Grand Prix       N     Manual 5-spd  1993
# 99  Brooklands/Brklnds L       N  Automatic 4-spd  1993
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Set Custom Index
#
# If we want to set a custom index using the make and model columns, then we can pass a list to ``.set_index()``.

# %%
assigned_index_df = df.set_index(["make","model"])

assigned_index_df
# Out:
#                                   city08  cylinders fuelType  highway08  \
# make        model
# Rolls-Royce Brooklands/Brklnds L       9          8  Premium         13
# Ferrari     Testarossa                 9         12  Regular         14
# Dodge       B350 Wagon 2WD             9          8  Regular         10
#             B150/B250 Wagon 2WD        9          8  Regular         11
#             B150/B250 Wagon 2WD       10          8  Regular         12
# ...                                  ...        ...      ...        ...
# Toyota      Corolla                   23          4  Regular         30
#             Corolla                   23          4  Regular         30
#             Corolla                   23          4  Regular         31
#             Corolla                   23          4  Regular         26
# Dodge       Charger                   23          4  Regular         33
#
#                                      id mpgData            trany  year
# make        model
# Rolls-Royce Brooklands/Brklnds L  10087       N  Automatic 4-spd  1993
# Ferrari     Testarossa               10       N     Manual 5-spd  1985
# Dodge       B350 Wagon 2WD         1007       N  Automatic 3-spd  1985
#             B150/B250 Wagon 2WD    1004       N  Automatic 3-spd  1985
#             B150/B250 Wagon 2WD    1000       N  Automatic 3-spd  1985
# ...                                 ...     ...              ...   ...
# Toyota      Corolla               10006       Y     Manual 5-spd  1993
#             Corolla               10005       Y  Automatic 4-spd  1993
#             Corolla               10004       Y     Manual 5-spd  1993
#             Corolla               10003       Y  Automatic 3-spd  1993
# Dodge       Charger                 100       Y     Manual 5-spd  1985
#
# [100 rows x 8 columns]

# %% [markdown]
# Using this method, we can replace the default integer-based row index with two axis labels. This is considered a MultiIndex or a hierarchical index.
#
# Now DataFrame ``assigned_index_df`` is now indexed by more than one key, which we can sort on with ``.sort_index()``.

# %%
assigned_index_df.sort_index()
# Out:
#                                city08  cylinders fuelType  highway08     id  \
# make       model
# Alfa Romeo Spider Veloce 2000      19          4  Regular         25      1
# Audi       100                     17          6  Premium         24  10014
#            100                     17          6  Premium         22  10013
# BMW        740i                    14          8  Premium         20  10015
#            740il                   14          8  Premium         20  10016
# ...                               ...        ...      ...        ...    ...
# Volkswagen Golf III / GTI          21          4  Regular         29  10008
#            Jetta III               18          4  Regular         26  10009
#            Jetta III               20          4  Regular         28  10010
# Volvo      240                     18          4  Regular         23  10011
#            240                     19          4  Regular         26  10012
#
#                               mpgData            trany  year
# make       model
# Alfa Romeo Spider Veloce 2000       Y     Manual 5-spd  1985
# Audi       100                      N     Manual 5-spd  1993
#            100                      Y  Automatic 4-spd  1993
# BMW        740i                     N  Automatic 5-spd  1993
#            740il                    N  Automatic 5-spd  1993
# ...                               ...              ...   ...
# Volkswagen Golf III / GTI           Y     Manual 5-spd  1993
#            Jetta III                N  Automatic 4-spd  1993
#            Jetta III                N     Manual 5-spd  1993
# Volvo      240                      Y  Automatic 4-spd  1993
#            240                      Y     Manual 5-spd  1993
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Sorting by Index in Descending Order

# %%
assigned_index_df.sort_index(ascending=False)
# Out:
#                                city08  cylinders fuelType  highway08     id  \
# make       model
# Volvo      240                     18          4  Regular         23  10011
#            240                     19          4  Regular         26  10012
# Volkswagen Jetta III               18          4  Regular         26  10009
#            Jetta III               20          4  Regular         28  10010
#            Golf III / GTI          18          4  Regular         26  10007
# ...                               ...        ...      ...        ...    ...
# BMW        740il                   14          8  Premium         20  10016
#            740i                    14          8  Premium         20  10015
# Audi       100                     17          6  Premium         24  10014
#            100                     17          6  Premium         22  10013
# Alfa Romeo Spider Veloce 2000      19          4  Regular         25      1
#
#                               mpgData            trany  year
# make       model
# Volvo      240                      Y  Automatic 4-spd  1993
#            240                      Y     Manual 5-spd  1993
# Volkswagen Jetta III                N  Automatic 4-spd  1993
#            Jetta III                N     Manual 5-spd  1993
#            Golf III / GTI           N  Automatic 4-spd  1993
# ...                               ...              ...   ...
# BMW        740il                    N  Automatic 5-spd  1993
#            740i                     N  Automatic 5-spd  1993
# Audi       100                      N     Manual 5-spd  1993
#            100                      Y  Automatic 4-spd  1993
# Alfa Romeo Spider Veloce 2000       Y     Manual 5-spd  1985
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Working With the DataFrame axis
#
# When you use .sort_index() without passing any explicit arguments, it uses axis=0 as a default argument. The axis of a DataFrame refers to either the index (axis=0) or the columns (axis=1).
#
# #### Using Column Labels to Sort
#
# Setting axis to 1 sorts the columns of your DataFrame based on the column labels:

# %%
df.sort_index(axis=1)
# Out:
#     city08  cylinders fuelType  highway08     id         make  \
# 99       9          8  Premium         13  10087  Rolls-Royce
# 1        9         12  Regular         14     10      Ferrari
# 80       9          8  Regular         10   1007        Dodge
# 47       9          8  Regular         11   1004        Dodge
# 3       10          8  Regular         12   1000        Dodge
# ..     ...        ...      ...        ...    ...          ...
# 10      23          4  Regular         30  10006       Toyota
# 9       23          4  Regular         30  10005       Toyota
# 8       23          4  Regular         31  10004       Toyota
# 7       23          4  Regular         26  10003       Toyota
# 2       23          4  Regular         33    100        Dodge
#
#                    model mpgData            trany  year
# 99  Brooklands/Brklnds L       N  Automatic 4-spd  1993
# 1             Testarossa       N     Manual 5-spd  1985
# 80        B350 Wagon 2WD       N  Automatic 3-spd  1985
# 47   B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# 3    B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# ..                   ...     ...              ...   ...
# 10               Corolla       Y     Manual 5-spd  1993
# 9                Corolla       Y  Automatic 4-spd  1993
# 8                Corolla       Y     Manual 5-spd  1993
# 7                Corolla       Y  Automatic 3-spd  1993
# 2                Charger       Y     Manual 5-spd  1985
#
# [100 rows x 10 columns]

# %% [markdown]
# The columns of your DataFrame are sorted from left to right in ascending alphabetical order.
#
# ### Working With Missing Data
#
# The following piece of code creates a new column based on the existing mpgData column, mapping True where mpgData equals Y and NaN where it doesn’t:

# %%
df["mpgdata_"] = df["mpgData"].map({"Y":True})
df
# Out:
#     city08  cylinders fuelType  highway08     id         make  \
# 99       9          8  Premium         13  10087  Rolls-Royce
# 1        9         12  Regular         14     10      Ferrari
# 80       9          8  Regular         10   1007        Dodge
# 47       9          8  Regular         11   1004        Dodge
# 3       10          8  Regular         12   1000        Dodge
# ..     ...        ...      ...        ...    ...          ...
# 10      23          4  Regular         30  10006       Toyota
# 9       23          4  Regular         30  10005       Toyota
# 8       23          4  Regular         31  10004       Toyota
# 7       23          4  Regular         26  10003       Toyota
# 2       23          4  Regular         33    100        Dodge
#
#                    model mpgData            trany  year mpgdata_
# 99  Brooklands/Brklnds L       N  Automatic 4-spd  1993      NaN
# 1             Testarossa       N     Manual 5-spd  1985      NaN
# 80        B350 Wagon 2WD       N  Automatic 3-spd  1985      NaN
# 47   B150/B250 Wagon 2WD       N  Automatic 3-spd  1985      NaN
# 3    B150/B250 Wagon 2WD       N  Automatic 3-spd  1985      NaN
# ..                   ...     ...              ...   ...      ...
# 10               Corolla       Y     Manual 5-spd  1993     True
# 9                Corolla       Y  Automatic 4-spd  1993     True
# 8                Corolla       Y     Manual 5-spd  1993     True
# 7                Corolla       Y  Automatic 3-spd  1993     True
# 2                Charger       Y     Manual 5-spd  1985     True
#
# [100 rows x 11 columns]

# %% [markdown]
# If we sort on a column with missing data, then the rows with the missing values will appear at the end of your DataFrame.

# %%
df.sort_values("mpgdata_")
# Out:
#     city08  cylinders fuelType  highway08     id        make          model  \
# 32      15          8  Premium         23  10026    Cadillac       Eldorado
# 46      18          6  Premium         24  10039      Nissan         Maxima
# 55      18          6  Regular         26  10047       Dodge         Spirit
# 83      18          6  Regular         26  10072  Oldsmobile  Cutlass Ciera
# 49      18          6  Regular         26  10041       Dodge        Dynasty
# ..     ...        ...      ...        ...    ...         ...            ...
# 52      21          4  Regular         26  10044       Dodge         Spirit
# 23      21          4  Regular         28  10018       Buick        Century
# 81      21          4  Regular         28  10070  Oldsmobile  Cutlass Ciera
# 53      22          4  Regular         29  10045       Dodge         Spirit
# 92      22          4  Regular         29  10080    Plymouth        Acclaim
#
#    mpgData            trany  year mpgdata_
# 32       Y  Automatic 4-spd  1993     True
# 46       Y     Manual 5-spd  1993     True
# 55       Y  Automatic 4-spd  1993     True
# 83       Y  Automatic 4-spd  1993     True
# 49       Y  Automatic 4-spd  1993     True
# ..     ...              ...   ...      ...
# 52       N  Automatic 3-spd  1993      NaN
# 23       N  Automatic 3-spd  1993      NaN
# 81       N  Automatic 3-spd  1993      NaN
# 53       N     Manual 5-spd  1993      NaN
# 92       N     Manual 5-spd  1993      NaN
#
# [100 rows x 11 columns]

# %% [markdown]
# To change that behavior and have the missing data appear first in the DataFrame, we can set ``na_position`` to first.

# %%
df.sort_values("mpgdata_",na_position="first")
# Out:
#     city08  cylinders fuelType  highway08     id         make  \
# 99       9          8  Premium         13  10087  Rolls-Royce
# 1        9         12  Regular         14     10      Ferrari
# 80       9          8  Regular         10   1007        Dodge
# 47       9          8  Regular         11   1004        Dodge
# 3       10          8  Regular         12   1000        Dodge
# ..     ...        ...      ...        ...    ...          ...
# 74      17          6  Regular         25  10064      Mercury
# 85      17          6  Regular         27  10074   Oldsmobile
# 29      17          6  Regular         26  10023        Buick
# 7       23          4  Regular         26  10003       Toyota
# 2       23          4  Regular         33    100        Dodge
#
#                    model mpgData            trany  year mpgdata_
# 99  Brooklands/Brklnds L       N  Automatic 4-spd  1993      NaN
# 1             Testarossa       N     Manual 5-spd  1985      NaN
# 80        B350 Wagon 2WD       N  Automatic 3-spd  1985      NaN
# 47   B150/B250 Wagon 2WD       N  Automatic 3-spd  1985      NaN
# 3    B150/B250 Wagon 2WD       N  Automatic 3-spd  1985      NaN
# ..                   ...     ...              ...   ...      ...
# 74                 Sable       Y  Automatic 4-spd  1993     True
# 85       Cutlass Supreme       Y  Automatic 4-spd  1993     True
# 29                 Regal       Y  Automatic 4-spd  1993     True
# 7                Corolla       Y  Automatic 3-spd  1993     True
# 2                Charger       Y     Manual 5-spd  1985     True
#
# [100 rows x 11 columns]

# %% [markdown]
# ### Using .sort_values() In Place
#
# Both ``.sort_values()`` and ``.sort_index()`` have returned DataFrame objects. That’s because sorting in pandas doesn’t work in place by default.
#
#
# However, we can modify the original DataFrame directly by specifying the optional parameter inplace with the value of True.
#
# With inplace set to True, we modify the original DataFrame, so the sort methods return None.
#
# ```python
# df.sort_values("city08", inplace=True)
# ```
#
# or
#
# ```python
# df.sort_index(inplace=True)
# ```
